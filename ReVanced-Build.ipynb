# %%
folder="build"
drive_id="1DjDTyrYLRcn7W6nwI9SEi_xibd-rwixB"
integrations_ver="0.21.9"
patches_ver="2.12.2"
cli_ver="2.5.2"
cmd_line="-e microg-support -e custom-branding -e hide-shorts-button -e hide-watermark -e hide-infocard-suggestions -e hide-autoplay-button -e fenster-swipe-controls -e hdr-max-brightness"

# !apt update
# !apt upgrade

# !pip install gdown 
# !sleep 3

print("- Creating Folder...")
# !mkdir $folder
# %cd $folder
# !sleep 4

#Zulu JDK-17 download and install
# !wget https://cdn.azul.com/zulu/bin/zulu17.34.19-ca-jdk17.0.3-linux_amd64.deb
# !sleep 3

# !sudo apt install ./zulu17.34.19-ca-jdk17.0.3-linux_amd64.deb
# !java --version

# !sleep 5

print("- Checking Files...")
# !sleep 2
print("Integrations Version:")
print(integrations_ver)
# !sleep 1
print("Patches Version:")
print(patches_ver)
# !sleep 1
print("Cli Version:")
print(cli_ver)

# !sleep 3

# !wget "https://github.com/revanced/revanced-integrations/releases/download/v"$integrations_ver"/app-release-unsigned.apk"
# !wget "https://github.com/revanced/revanced-patches/releases/download/v"$patches_ver"/revanced-patches-"$patches_ver".jar"
# !wget "https://github.com/revanced/revanced-cli/releases/download/v"$cli_ver"/revanced-cli-"$cli_ver"-all.jar"

# !sleep 3

print(drive_id)
# !sleep 2
# !gdown $drive_id

print("- Preparing Files...")

# !mv app-release-unsigned.apk integrations.apk
# !mv "revanced-patches-"$patches_ver".jar" patches.jar
# !mv "revanced-cli-"$cli_ver"-all.jar" cli.jar
# !sleep 4

print("- Build Amoled Apk")
# !java -jar cli.jar -a youtube.apk -c -o amoled.apk -b patches.jar $cmd_line -m integrations.apk

# !sleep 3

print("- Build Non-Amoled Apk")
# !java -jar cli.jar -a youtube.apk -c -o non-amoled.apk -b patches.jar $cmd_line -e amoled -m integrations.apk

# !sleep 5

# !cd ..
# !pwd

print("- Done!")
